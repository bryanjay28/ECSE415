# %% [markdown]
# Bryan Jay - 260738764
#
# # Part 2 - Edge Detection
# ### 2.2 Laplacian of Gaussian

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# load image
image = cv2.imread('./woman.png', cv2.IMREAD_GRAYSCALE)

# take the gaussian blur of the image
woman = cv2.GaussianBlur(image, (3,3), 1)

# apply 5 x 5 laplacian filter to ther intensity channel
I_lap = cv2.Laplacian(woman, cv2.CV_32F, ksize=5)

# get the rows and columns
rows, cols = I_lap.shape[:2]
zeroCrossing = np.zeros(I_lap.shape)

# s_edge = zerocross(I_lap)
# print(z_edge)
# find the rows and columns 
for x in range(0, rows):
    for y in range(0, cols):
        if(I_lap[x,y] <= 0 ):
#         if(I_lap[x,y] == 0):
            zeroCrossing[x,y] = 255
        else:
            zeroCrossing[x,y] = 0
#         neg_count = 0
#         pos_count = 0
#         for a in range_inc(-1, 1):
#             for b in range_inc(-1, 1):
#                 if a != 0 and b != 0:
#                     if I_lap[x + a, y + b] < 0:
#                         neg_count += 1
#                     elif I_lap[x + a, y + b] > 0:
#                         pos_count += 1

#             # If all the signs around the pixel are the same
#             # and they're not all zero
#             # then it's not a zero crossing and an edge. 
#             # Otherwise, copy it to the edge map.
# #         if(neg_count > 0 and )
#         zeroCrossing[x,y] = ((neg_count > 0) and (pos_count > 0))

ret, zeroCrossing = cv2.threshold(I_lap, 255, 255, cv2.THRESH_BINARY)

# display images
plt.figure(figsize=(20, 20))
plt.subplot(131), plt.imshow(image, cmap="gray")
plt.title('Orginal Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132), plt.imshow(I_lap, cmap="gray")
plt.title('Laplacian filtered (5x5) image'), plt.xticks([]), plt.yticks([])
plt.subplot(133), plt.imshow(zeroCrossing, cmap="gray")
plt.title('Zero Edge Crossing image'), plt.xticks([]), plt.yticks([])
plt.show()
