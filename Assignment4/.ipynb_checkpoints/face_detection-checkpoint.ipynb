# %% [markdown]
# Bryan Jay - 260738764
#
# ## 1 - Data Acquisition

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

group_img = cv2.imread('./images/group-photo.jpg')

# display images
plt.figure(figsize=(20,20))
plt.subplot(111), plt.imshow(cv2.cvtColor(group_img, cv2.COLOR_BGR2RGB))
plt.title("Group Image"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
nph_img = []
cs_img = []
tm_img = []

size = (100,100)
for i in range(11):
    path = './images/{title}{index}.jpg'
    nph_resized = cv2.resize(cv2.imread(path.format(title='nph', index=i)), size)
    nph_img.append(cv2.cvtColor(nph_resized, cv2.COLOR_BGR2GRAY))
    
    cs_resized = cv2.resize(cv2.imread(path.format(title='cs', index=i)), size)
    cs_img.append(cv2.cvtColor(cs_resized, cv2.COLOR_BGR2GRAY))
    
    tm_resized = cv2.resize(cv2.imread(path.format(title='tm', index=i)), size)
    tm_img.append(cv2.cvtColor(tm_resized, cv2.COLOR_BGR2GRAY))


plt.figure(figsize=(15,15))
for i in range(11):
    plt.subplot(4,3,1+i), plt.imshow(nph_img[i], cmap='gray')
    plt.title("Neil Patrick Harris img " + str(i)), plt.xticks([]), plt.yticks([])
plt.show()

plt.figure(figsize=(15,15))
for i in range(11):
    plt.subplot(4,3,1+i), plt.imshow(cs_img[i], cmap='gray')
    plt.title("Colby Smulder img " + str(i)), plt.xticks([]), plt.yticks([])
plt.show()

plt.figure(figsize=(15,15))
for i in range(11):
    plt.subplot(4,3,1+i), plt.imshow(tm_img[i], cmap='gray')
    plt.title("Josh Radnor img " + str(i)), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# I selected the group photo because they were all looking at the camera and the lighting was good in the image. Additionally the background is all black so there is good contrast between the background and the lighter faces of the 3 people. In order to chose the 33 images, I looked for images where the celeb had good lighting and the face was easy to see in the background. The group of images have different features in them, since i took some rotated differently, some with teeth showing and with the head slightly rotated as well. All the images are resized to (100,100) so that M = 10,000

# %% [markdown]
# ## 2 - Eigenvector Representation

# %%
# create the vector for each image, for the image
nph_vec = [np.reshape(nph_img[i], (nph_img[i].shape[0]*nph_img[i].shape[1],-1)) for i in range(len(nph_img))]
cs_vec = [np.reshape(cs_img[i], (cs_img[i].shape[0]*cs_img[i].shape[1],-1)) for i in range(len(cs_img))]
tm_vec = [np.reshape(tm_img[i], (tm_img[i].shape[0]*tm_img[i].shape[1],-1)) for i in range(len(tm_img))]

# put all the vectors into single array where each cell contains the image
nph_arr = np.hstack((nph_vec))
cs_arr = np.hstack((cs_vec))
tm_arr = np.hstack((tm_vec))

D = np.hstack((nph_arr, cs_arr, tm_arr))

# %%
# method from notes
mean_D = D.mean(axis=0)
D = D - mean_D
# find the variance of the data
# get N 
N = D.shape[1]
# get the variances
var = [(1/(N-1)) * np.dot(np.dot(v.transpose(), np.dot(D, np.transpose(D))), v) for v in D.transpose()]

print(var)
# Out:
# [369888534874380.25, 146007056566939.62, 108555225685505.27, 509141237162036.9, 134069543476789.45, 64127437250458.484, 347854676980997.6, 477547167349510.75, 349873046347408.0, 235392319747580.88, 176127028560711.7, 400250226046311.0, 581623424643380.4, 581238177516330.0, 270220298011213.0, 553916436080219.1, 480744529134258.1, 555140810536793.44, 137051238791053.06, 516029069429517.25, 710753235353199.8, 532279550840147.06, 175442545781804.1, 373418993498085.75, 439214022761496.8, 376990049326818.56, 479664016764354.5, 76250286771377.7, 340624893714859.1, 387934404259480.2, 279406811703434.44, 526742755817113.75, 146708516468044.75]

# %%
# plot the variance data in descending order 
variance = sorted(var, reverse=True)
print(variance)

plt.title('Variances plotted in reverse descending order')
plt.scatter(range(1, 34), variance)
plt.show()
# Out:
# [886220254714181.5, 792743582088909.9, 792612004464834.5, 641948168290590.4, 605506791956829.5, 588012289319817.5, 576978638834682.9, 555859504984574.06, 548281791261546.4, 544941698293904.75, 543498872751940.0, 512035158476230.5, 510539482960903.25, 493769599720315.1, 444924211234461.9, 414513616510098.1, 410828179151555.1, 396783855317074.6, 389110044984195.4, 381197481568860.5, 372936157448546.4, 350960100505689.06, 293115044832272.0, 249215143553652.25, 182768642566872.3, 163401840986772.12, 158792510528592.56, 151600737911824.25, 148630904000683.88, 140515821681327.92, 118709999266442.83, 77390123442807.44, 64360179102340.32]

# %%
# find D^2 
# D2 = np.dot(D, np.transpose(D))
# eig_vectors, eig_vals = np.linalg.eig(D2)

# %%
# print(len(eig_vectors[1:10001]))
# plt.scatter(range(2,10001), eig_vectors[1:10000])
# plt.title('Eigen vectors displayed')
# plt.show()

# plt.plot(eig_vals[0])
# plt.title('Eigen values distribution')
# plt.show()

# %%
mean, eigvectors = cv2.PCACompute(D.transpose(), mean=None, maxComponents=50)
# print(mean[0].shape)
# print(eigvectors[0].shape)
# shape the eigen faces array
meanface = mean[0].reshape(size)
# print(meanface)

# plt.scatter(range(1,10001), mean[0])
# plt.title('Eigen v diectors stribution')
# plt.show()

# build eigen faces on one another
# plt.figure(figsize=(15,15))
# eigenfaces = []
# for eigvector in eigvectors:
#     eigenface = eigvector.reshape(size)
#     eigenfaces.append(eigenface)
plt.imshow(meanface, cmap = "gray")
plt.title("mean image"), plt.xticks([]), plt.yticks([])
plt.show()


output = 0
for eig_vec in eigvectors:
    eigface = eig_vec.reshape(size)
    output += eigface
plt.imshow(output, cmap='gray')
plt.title('Eigen Faces Image'), plt.axis('off')
plt.show()

# total = 0
# for i in range(33):
#     output = np.add(meanface, eigenfaces[i]*100)
#     total += output
# # output = cv2.resize(output, (0,0), fx=2, fy=2)
# plt.subplot(122).imshow(total, cmap = "gray")
# plt.title("eigenface Image"), plt.xticks([]), plt.yticks([])
# plt.show()

# %%
# find the the projection matrix, mean, variance
# get data in array of rows of images 
train_img =  D.transpose()
# print(train_img.shape)

data_size = train_img.shape

# find the mean and center data
mean = train_img.mean(axis=0)
train_img = train_img - mean

# find the covatiance matrix and the eigenvalues and eigenvectors 
# eig_vectors = train_img.components_
cov = np.dot(train_img, train_img.transpose())
# print(cov.shape)
eig_values, eig_vectors = np.linalg.eigh(cov)
# print(eig_values.shape)
# print(eig_vectors.shape)
# find the projection matrix and take the reverse to get the higher order variances
v = np.dot(train_img.transpose(), eig_vectors).transpose()[::-1]

# display the mean face compilation
mean_face = mean.reshape(size)

plt.imshow(mean_face, cmap='gray')
plt.title('Image for the mean face'), plt.axis('off')
plt.show()

# eig_faces = []
# for eig_vector in eig_vectors:
#     eig_face = eig_vector.reshape(size)
#     eig_faces = np.add(mean_face, eig_face)
    
# print(eig_vectors.shape)
# # calculate the eigenfaces
# eig_faces = []
# for eig_vec in eig_vectors:
#     eigface = eig_vec.reshape(size)
#     eig_faces.append(eigface)
#     plt.imshow(eigenface, cmap='gray')
#     plt.title('Eigen Faces Image'), plt.axis('off')
#     plt.show()
    
# for eigvector in eig_vectors:
#     eigenface = eigvector.reshape(size)
#     eigenfaces.append(eigenface)
# plt.subplot(121).imshow(meanface, cmap = "gray")
# plt.title("mean image"), plt.xticks([]), plt.yticks([])

# for i in range(33):
#     output = np.add(meanface, eigenfaces[i]*100)
# output = cv2.resize(output, (0,0), fx=2, fy=2)
# plt.subplot(122).imshow(output, cmap = "gray")
# plt.title("eigenface Image"), plt.xticks([]), plt.yticks([])
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-223-865e82ae0aa1> in <module>()
#      29 output = 0
#      30 for eig_vec in eig_vectors:
# ---> 31     eigface = eig_vec.reshape(size)
#      32     output += eigface
#      33 plt.imshow(output, cmap='gray')
#
# ValueError: cannot reshape array of size 33 into shape (100,100)

# %%
# find the variances
var = np.sqrt(eig_values)[::-1]

print(var)

plt.title('Variances explained by every vector')
plt.scatter(range(1, 34), var)
plt.show()
# Out:
# [12861.86137459 10033.37135701  9378.25690938  7599.23889339
#   6356.5499592   6063.76238957  5140.22806722  4735.64447023
#   4591.18697847  4285.18420843  4022.71163446  3859.73600159
#   3596.02772687  3506.93516774  3337.48747042  3238.03302237
#   3094.98458665  3001.80014224  2900.93074971  2693.64872205
#   2645.67420799  2557.13925723  2498.64174542  2432.12542879
#   2344.25991615  2206.42552557  2132.50485306  2107.24184515
#   2009.6213356   1942.82837988  1868.7182689   1646.23340735
#             nan]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt

# %%
### put the images in rows instead of columns 
D_row = D.transpose()

# initalize the PCA object, with n components = 33 since we have 33 images 
n_components = 33
pca = PCA(n_components=n_components)

# fit the trainning data and center it beforehand
train_img = pca.fit_transform(D_row)
print(train_img.shape)

eig_vectors = pca.components_

# calculate the mean of the data and display the mean face
mean = pca.mean_
print(mean)
meanface = mean.reshape(size)

output = 0
for eig_vec in eig_vectors:
    eigface = eig_vec.reshape(size)
    output += eigface
plt.figure(figsize=(15,15))
plt.subplot(121), plt.imshow(meanface, cmap='gray')
plt.title('Mean Image'), plt.axis('off')
plt.subplot(122), plt.imshow(output, cmap='gray')
plt.title('Eigen Faces Image'), plt.axis('off')
plt.show()

eig_faces = []
for eig_vec in eig_vectors:
    eigface = eig_vec.reshape(size)
    eig_faces.append(eigface)

plt.figure(figsize=(15,15))
for i, eig_face in enumerate(eig_faces):
    plt.subplot(6,6,1+i), plt.imshow(eig_face, cmap='gray')
    plt.title('Eigen Faces Image'), plt.axis('off')
plt.show()
# Out:
# (33, 33)
# [-52.44417576 -57.50478182 -58.41387273 ... -23.08053939 -24.41387273
#  -29.59569091]

# %%
var = pca.explained_variance_ratio_

plt.title('Variances explained by every vector')
plt.plot(range(1, 34), var)
plt.xlabel('Component Number'), plt.ylabel('Explained Variance')
plt.show()
